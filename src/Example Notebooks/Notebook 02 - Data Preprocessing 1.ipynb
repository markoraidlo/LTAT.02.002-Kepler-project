# %%
# Imports
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.ndimage as ndimage

# Parameters
# %matplotlib inline
plt.rcParams['figure.figsize'] = (12, 6)

# %%
# Load in the test data only for now.
from pathlib import Path # Multiplatform compatibility
test_data = pd.read_csv(Path("data") / 'exoTest.csv')

# %%
# Renaming the columns
test_data.columns = [test_data.columns[i].replace("FLUX.", "") for i in range(len(test_data.columns))]

# %%
# Smoothen the data out a bit
labels = test_data.LABEL

# %%
test_data = test_data.drop(["LABEL"], axis=1)

# %%
test_data.iloc[1].plot()

# %%
test_data.iloc[1] = ndimage.filters.gaussian_filter(test_data.iloc[1], sigma=15) # smooths epicly
# will add this to py file...

# %%
len(test_data)
# Out:
# 570

# %%
test_data.iloc[1].plot()

# %%
# g - bound between 1, -1
# f - unit deviation
g = lambda row : (row - np.mean(row)) / (np.max(row) - np.min(row))
f = lambda row : (row - np.mean(row)) / (np.std(row))

# %%
g(test_data.iloc[1]).plot()
